# %%
import random
import numpy as np
import pandas as pd

# %%
#using numpy's randint
df = pd.DataFrame(np.random.randint(1000,10000,size=(10000, 34)), columns=('date', 'no_students','BA_milk_P(litres)', 'BA_bread_P(loaves)', 'BA_sausage_P(no)',
                                                                            'BA_milk_UN(litres)', 'BA_bread_UN(loaves)', 'BA_sausage_UN(no)',
                                                                            'LA_rice_P(kg)', 'LA_beans_P(kg)', 'LA_maize_P(kg)', 'LA_maize_flour_P(kg)', 'LA_meat_P(kg)', 'LA_cabbage_P(no)',
                                                                            'LA_rice_UN(kg)', 'LA_beans_UN(kg)', 'LA_maize_UN(kg)', 'LA_maize_flour_UN(kg)', 'LA_meat_UN(kg)', 'LA_cabbage_UN(no)', 'Lplate_waste(kg)',
                                                                            'SA_rice_P(kg)', 'SA_beans_P(kg)', 'SA_maize_P(kg)', 'SA_maize_flour_P(kg)', 'SA_meat_P(kg)', 'SA_cabbage_P(no)',
                                                                            'SA_rice_UN(kg)', 'SA_beans_UN(kg)', 'SA_maize_UN(kg)', 'SA_maize_flour_UN(kg)', 'SA_meat_UN(kg)', 'SA_cabbage_UN(no)', 'Splate_waste(kg)'))

# %%
# create a new column 
df['date'] = 'Laura'
df['no_students'] = 'Laura'
df['Lplate_waste(kg)'] = 'Laura'
df['Splate_waste(kg)'] = 'Laura'
df['BA_milk_P(litres)'] = 'Laura'
df['BA_bread_P(loaves)'] = 'Laura'
df['BA_sausage_P(no)'] = 'Laura'
df['BA_milk_UN(litres)'] = 'Laura'
df['BA_bread_UN(loaves)'] = 'Laura'
df['BA_sausage_UN(no)'] = 'Laura'
df['LA_rice_P(kg)'] = 'Laura'
df['LA_beans_P(kg)'] = 'Laura'
df['LA_maize_P(kg)'] = 'Laura'
df['LA_maize_flour_P(kg)'] = 'Laura'
df['LA_meat_P(kg)'] = 'Laura'
df['LA_cabbage_P(no)'] = 'Laura'
df['LA_rice_UN(kg)'] = 'Laura'
df['LA_beans_UN(kg)'] = 'Laura'
df['LA_maize_UN(kg)'] = 'Laura'
df['LA_maize_flour_UN(kg)'] = 'Laura'
df['LA_meat_UN(kg)'] = 'Laura'
df['LA_cabbage_UN(no)'] = 'Laura'
df['SA_rice_P(kg)'] = 'Laura'
df['SA_beans_P(kg)'] = 'Laura'
df['SA_maize_P(kg)'] = 'Laura'
df['SA_maize_flour_P(kg)'] = 'Laura'
df['SA_meat_P(kg)'] = 'Laura'
df['SA_cabbage_P(no)'] = 'Laura'
df['SA_rice_UN(kg)'] = 'Laura'
df['SA_beans_UN(kg)'] = 'Laura'
df['SA_maize_UN(kg)'] = 'Laura'
df['SA_maize_flour_UN(kg)'] = 'Laura'
df['SA_meat_UN(kg)'] = 'Laura'
df['SA_cabbage_UN(no)'] = 'Laura'
df.head(5)
# Out:
#     date no_students BA_milk_P(litres) BA_bread_P(loaves) BA_sausage_P(no)  \
# 0  Laura       Laura             Laura              Laura            Laura
# 1  Laura       Laura             Laura              Laura            Laura
# 2  Laura       Laura             Laura              Laura            Laura
# 3  Laura       Laura             Laura              Laura            Laura
# 4  Laura       Laura             Laura              Laura            Laura
#
#   BA_milk_UN(litres) BA_bread_UN(loaves) BA_sausage_UN(no) LA_rice_P(kg)  \
# 0              Laura               Laura             Laura         Laura
# 1              Laura               Laura             Laura         Laura
# 2              Laura               Laura             Laura         Laura
# 3              Laura               Laura             Laura         Laura
# 4              Laura               Laura             Laura         Laura
#
# ...

# %%
for index, row in df.iterrows():
      df.at[index,'date'] = np.datetime64('2020-01-01')
    
df.head(5)
# Out:
#          date no_students BA_milk_P(litres) BA_bread_P(loaves)  \
# 0  2020-01-01       Laura             Laura              Laura
# 1  2020-01-01       Laura             Laura              Laura
# 2  2020-01-01       Laura             Laura              Laura
# 3  2020-01-01       Laura             Laura              Laura
# 4  2020-01-01       Laura             Laura              Laura
#
#   BA_sausage_P(no) BA_milk_UN(litres) BA_bread_UN(loaves) BA_sausage_UN(no)  \
# 0            Laura              Laura               Laura             Laura
# 1            Laura              Laura               Laura             Laura
# 2            Laura              Laura               Laura             Laura
# 3            Laura              Laura               Laura             Laura
# 4            Laura              Laura               Laura             Laura
#
#   LA_rice_P(kg) LA_beans_P(kg)  ... SA_maize_flour_P(kg) SA_meat_P(kg)  \
# ...

# %%
for index, row in df.iterrows():
    df.at[index,'BA_milk_P(litres)'] = random.randint(200,220)
    df.at[index,'BA_bread_P(loaves)'] = random.randint(400,420)
    df.at[index,'BA_sausage_P(no)'] = random.randint(480,500)
    df.at[index,'BA_milk_UN(litres)'] = random.randint(0,30)
    df.at[index,'BA_bread_UN(loaves)'] = random.randint(0,20)
    df.at[index,'BA_sausage_UN(no)'] = random.randint(0,25)
    df.at[index,'LA_rice_P(kg)'] = random.randint(100,130)
    df.at[index,'LA_beans_P(kg)'] = random.randint(110,130)
    df.at[index,'LA_maize_P(kg)'] = random.randint(110,130)
    df.at[index,'LA_maize_flour_P(kg)'] = random.randint(1000,1300)
    df.at[index,'LA_meat_P(kg)'] = random.randint(190,200)
    df.at[index,'LA_cabbage_P(no)'] = random.randint(10,100)
    df.at[index,'LA_rice_UN(kg)'] = random.randint(0,40)
    df.at[index,'LA_beans_UN(kg)'] = random.randint(0,20)
    df.at[index,'LA_maize_UN(kg)'] = random.randint(0,20)
    df.at[index,'LA_maize_flour_UN(kg)'] = random.randint(0,20)
    df.at[index,'LA_meat_UN(kg)'] = random.randint(0,10)
    df.at[index,'LA_cabbage_UN(no)'] = random.randint(0,10)
    df.at[index,'SA_rice_P(kg)'] = random.randint(130,150)
    df.at[index,'SA_beans_P(kg)'] = random.randint(130,150)
    df.at[index,'SA_maize_P(kg)'] = random.randint(130,150)
    df.at[index,'SA_maize_flour_P(kg)'] = random.randint(1000,1300)
    df.at[index,'SA_meat_P(kg)'] = random.randint(490,500)
    df.at[index,'SA_cabbage_P(no)'] = random.randint(10,100)
    df.at[index,'SA_rice_UN(kg)'] = random.randint(0,15)
    df.at[index,'SA_beans_UN(kg)'] = random.randint(0,20)
    df.at[index,'SA_maize_UN(kg)'] = random.randint(0,15)
    df.at[index,'SA_maize_flour_UN(kg)'] = random.randint(0,20)
    df.at[index,'SA_meat_UN(kg)'] = random.randint(0,5)
    df.at[index,'SA_cabbage_UN(no)'] = random.randint(0,10)
    df.at[index,'no_students'] = random.randint(100,500)
    df.at[index,'Lplate_waste(kg)'] = random.randint(0,100)
    df.at[index,'Splate_waste(kg)'] = random.randint(0,100)

df.head(5)
# Out:
#          date no_students BA_milk_P(litres) BA_bread_P(loaves)  \
# 0  2020-01-01         388               203                416
# 1  2020-01-01         492               201                400
# 2  2020-01-01         456               215                413
# 3  2020-01-01         383               204                417
# 4  2020-01-01         138               203                414
#
#   BA_sausage_P(no) BA_milk_UN(litres) BA_bread_UN(loaves) BA_sausage_UN(no)  \
# 0              488                 14                  14                21
# 1              499                 16                   3                 8
# 2              498                 10                  10                 1
# 3              493                 16                  13                24
# 4              492                  6                  20                 3
#
#   LA_rice_P(kg) LA_beans_P(kg)  ... SA_maize_flour_P(kg) SA_meat_P(kg)  \
# ...

# %%
#Export to csv
export_csv = df.to_csv (r'Fooda School Dataset2.csv', header=True)

# %%
fooda = pd.read_csv("Fooda School Dataset2.csv")

# %%
fooda.head(10)
# Out:
#          date  no_students  BA_milk_P(litres)  BA_bread_P(loaves)  \
# 0  01/01/2020          388                203                 416
# 1  02/01/2020          492                201                 400
# 2  03/01/2020          456                215                 413
# 3  04/01/2020          383                204                 417
# 4  05/01/2020          138                203                 414
# 5  06/01/2020          127                203                 413
# 6  07/01/2020          476                205                 402
# 7  08/01/2020          316                210                 419
# 8  09/01/2020          109                212                 411
# 9  10/01/2020          286                208                 417
#
#    BA_sausage_P(no)  BA_milk_UN(litres)  BA_bread_UN(loaves)  \
# 0               488                  14                   14
# 1               499                  16                    3
# ...

# %% [raw]
# Analytics

# %%
# Core Keras libraries

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Bidirectional
import tensorflow as tf

from keras.layers import LSTM
from keras.layers import Bidirectional

from scipy.ndimage import gaussian_filter1d
from scipy.signal import medfilt  
from numpy.random import seed
tf.compat.v1.set_random_seed(seed)
seed(1)
tf.random.set_seed(1)
# Out:
# Using TensorFlow backend.

# %%
# Other essential libraries

import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from numpy import array

# %%
# Make our plot a bit formal
font = {'family' : 'Arial',
        'weight' : 'normal',
        'size'   : 20}
plt.rc('font', **font)

# %%
# Set input number of timestamps and training days
n_timestamp = 10
train_days = 8000  # number of days to train from
testing_days = 2000 # number of days to be predicted
n_epochs = 100
filter_on = 1

# Select model type
# 1: Single cell
# 2: Stacked
# 3: Bidirectional
#
model_type = 2

# %%
if filter_on == 1:
    #In here, we perform median filter and Gaussian filter on the dataset.
    fooda['BA_milk_P(litres)'] = medfilt(fooda['BA_milk_P(litres)'], 3)
    fooda['BA_milk_P(litres)'] = gaussian_filter1d(fooda['BA_milk_P(litres)'], 1.2)

# %%
# Set number of training and testing data
train_set = fooda[0:train_days].reset_index(drop=True)
test_set = fooda[train_days: train_days+testing_days].reset_index(drop=True)
training_set = train_set.iloc[:, 2:3].values
testing_set = test_set.iloc[:, 2:3].values

# %%
# Normalize data first

sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)
testing_set_scaled = sc.fit_transform(testing_set)

# %%
# Split data into n_timestamp

def data_split(sequence, n_timestamp):
    X = []
    y = []
    for i in range(len(sequence)):
        end_ix = i + n_timestamp
        if end_ix > len(sequence)-1:
            break
        # i to end_ix as input
        # end_ix as target output
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
X_train, y_train = data_split(training_set_scaled, n_timestamp)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)

X_test, y_test = data_split(testing_set_scaled, n_timestamp)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
#Preview reshaped data 
print(X_train.shape)
print(X_test.shape)
# Out:
# (7990, 10, 1)
# (1990, 10, 1)

# %%
if model_type == 1:
    # Single cell LSTM
    model = Sequential()
    model.add(LSTM(units = 50, activation='relu',input_shape = (X_train.shape[1], 1)))
    model.add(Dense(units = 1))
if model_type == 2:
    # Stacked LSTM
    model = Sequential()
    model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(X_train.shape[1], 1)))
    model.add(LSTM(50, activation='relu'))
    model.add(Dense(1))
if model_type == 3:
    # Bidirectional LSTM
    model = Sequential()
    model.add(Bidirectional(LSTM(50, activation='relu'), input_shape=(X_train.shape[1], 1)))
    model.add(Dense(1))

# %%
# Start training

model.compile(optimizer = 'adam', loss = 'mean_squared_error')
history = model.fit(X_train, y_train, epochs = n_epochs, batch_size = 32)
loss = history.history['loss']
epochs = range(len(loss))
# Out:
# Epoch 1/100
# 7990/7990 [==============================] - 4s 497us/step - loss: 0.0419
# Epoch 2/100
# 7990/7990 [==============================] - 3s 392us/step - loss: 0.0064
# Epoch 3/100
# 7990/7990 [==============================] - 3s 394us/step - loss: 0.0027
# Epoch 4/100
# 7990/7990 [==============================] - 3s 398us/step - loss: 0.0015
# Epoch 5/100
# 7990/7990 [==============================] - 3s 388us/step - loss: 0.0013
# Epoch 6/100
# 7990/7990 [==============================] - 3s 390us/step - loss: 0.0010
# Epoch 7/100
# 7990/7990 [==============================] - 3s 391us/step - loss: 9.1766e-04
# Epoch 8/100
# 7990/7990 [==============================] - 3s 401us/step - loss: 8.1718e-04
# Epoch 9/100
# 7990/7990 [==============================] - 3s 408us/step - loss: 8.9657e-04
# Epoch 10/100
# 7990/7990 [==============================] - 3s 412us/step - loss: 7.3481e-04
# Epoch 11/100
# ...

# %%
# Get predicted data
y_predicted = model.predict(X_test)

# 'De-normalize' the data
y_predicted_descaled = sc.inverse_transform(y_predicted)
y_train_descaled = sc.inverse_transform(y_train)
y_test_descaled = sc.inverse_transform(y_test)
y_pred = y_predicted.ravel()
y_pred = [round(yx, 2) for yx in y_pred]
y_tested = y_test.ravel()

# %%
# Show results
plt.figure(figsize=(20,15))

plt.subplot(3, 1, 1)
plt.plot(fooda['no_students'], color = 'black', linewidth=1, label = 'True value')
plt.ylabel("no_students")
plt.xlabel("Day")
plt.title("All data")


plt.subplot(3, 2, 3)
plt.plot(y_test_descaled, color = 'black', linewidth=1, label = 'True value')
plt.plot(y_predicted_descaled, color = 'red',  linewidth=1, label = 'Predicted')
plt.legend(frameon=False)
plt.ylabel("no_students")
plt.xlabel("Day")
plt.title("Predicted data (n days)")

plt.subplot(3, 2, 4)
plt.plot(y_test_descaled[0:75], color = 'black', linewidth=1, label = 'True value')
plt.plot(y_predicted_descaled[0:75], color = 'red', label = 'Predicted')
plt.legend(frameon=False)
plt.ylabel("no_students")
plt.xlabel("Day")
plt.title("Predicted data (first 75 days)")
# Out:
# Text(0.5, 1.0, 'Predicted data (first 75 days)')

# %%
#plt.subplot(3, 2, 4)
plt.figure(figsize=(20,15))
plt.plot(y_test_descaled[0:75], color = 'black', linewidth=1, label = 'True value')
plt.plot(y_predicted_descaled[0:75], color = 'red', label = 'Predicted')
plt.legend(frameon=False)
plt.ylabel("BA_milk_P(litres)")
plt.xlabel("Day")
plt.title("Predicted data (first 75 days)")
# Out:
# Text(0.5, 1.0, 'Predicted data (first 75 days)')

# %%
plt.savefig('BA_milk_P(litres)')
